# %%
import math 
import cv2
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter

# %%
def derivadaX(img):

# %%
img = cv2.imread('car.jpg')
plt.imshow(img)

# %%
grayimage = problema_cinco(img)

# %%
test_image = test(grayimage)
result = gaussian_filter(test_image, sigma=5)
plt.imshow(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-72a5b5164da5> in <module>
#       1 test_image = test(grayimage)
#       2 result = gaussian_filter(test_image, sigma=5)
# ----> 3 plt.imshow(result)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
def test(img): 
    #h,w = img.shape
    #dx_image = img[:,1:w-1] - img[:,0:w-2]
    
    dx_image = np.diff(img, axis=1)
    plt.imshow(dx_image)
    return dx_image

# %%
def problema_cinco(img):
    alto = img.shape[0]
    ancho = img.shape[1]
    gray_ponderado = np.zeros((alto, ancho, 1))
    
    for i in range(0, alto):
        for j in range(0, ancho):
            pixel = img[i,j]
            gray_ponderado[i,j] = int(0.299*pixel[2] + 0.587*pixel[1] + 0.114*pixel[0])
    
    cv2.imwrite("Imagen_ponderada.jpg", gray_ponderado)
    imgTemp = cv2.imread("Imagen_ponderada.jpg")
    plt.imshow(imgTemp)
    return imgTemp
